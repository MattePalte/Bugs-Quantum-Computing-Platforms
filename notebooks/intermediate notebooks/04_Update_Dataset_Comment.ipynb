# %% [markdown]
# Goal: This notebook is used to update the metadata after the update of the dataset. Note that the change of the dataset consists mainly in the fix of some typos in the annotator's comment.

# %%
import json
import os
import pandas as pd

# %%
PATH_DATASET = "../artifacts/annotation_bugs.csv"
df_bugs = pd.read_csv(PATH_DATASET)
df_bugs.head()
# Out:
#      id real       type                 repo  \
# 0     1  bug  Classical  Qiskit/qiskit-ignis
# 1    10  bug    Quantum  Qiskit/qiskit-ignis
# 2  1010  bug    Quantum    Qiskit/qiskit-aer
# 3  1012  bug  Classical    Qiskit/qiskit-aer
# 4  1019  bug    Quantum    Qiskit/qiskit-aer
#
#                                 commit_hash                 component  \
# 0  ec1b4ce759f1fb8ba0242dd6c4a309fa1b586666  Quantum State Evaluation
# 1  e696fee3e52550f50fb240a4c6356c61c9f01725  Quantum State Evaluation
# 2  dc7a2413e6c373455c00cff51e37eaaa17a4a7ac             Optimizations
# 3  7de864cc989b354d0ad1febbd62b891270927b6b                   Testing
# 4  f3b4303f478ff84bf8da15761827287d3a2f16e4                 Simulator
#
#                             symptom  \
# 0        Crash - OS/PL Error, Crash
# 1                  Incorrect Output
# 2  Crash - Application Error, Crash
# 3                      Failing Test
# 4                  Incorrect Output
#
#                                          bug_pattern  \
# 0                             Missing Error Handling
# 1                    Incorrect Numerical Computation
# 2                                    Barrier Related
# 3  Flaky Test, Misconfiguration, Misconfiguration...
# 4                        API Misuse - Internal, Typo
#
#                                              comment  \
# 0  From fixer: "Currently, cvx_fit does not check...
# 1  Reporter: "ignis.characterization.calibrations...
# 2  Fixer: "Currently qubit truncation will fail f...
# 3  Fix issue where the "diagonal" gate is checked...
# 4  Fixer: "The new Diagonal terra gate was being ...
#
#                                         localization
# 0  https://github.com/Qiskit/qiskit-ignis/commit/...
# 1  https://github.com/Qiskit/qiskit-ignis/commit/...
# 2  https://github.com/Qiskit/qiskit-aer/commit/dc...
# 3  https://github.com/Qiskit/qiskit-aer/commit/7d...
# 4  https://github.com/Qiskit/qiskit-aer/commit/f3...

# %%
PATH_REPOS = "../artifacts/minimal_bugfixes"
os.listdir(PATH_REPOS)
# Out:
# ['mitiq',
#  'qsharp-runtime',
#  'strawberryfields',
#  'tequila',
#  'pennylane',
#  'qiskit-terra',
#  'qiskit-aer',
#  'rules.md',
#  'qsharp-compiler',
#  'amazon-braket-sdk-python',
#  'dwave-system',
#  'qiskit-ignis',
#  'OpenQL',
#  'ProjectQ',
#  'pyquil',
#  'QuantumLibraries',
#  'qulacs',
#  'xacc',
#  'Cirq']

# %%
REPOS = ['mitiq',
 'qsharp-runtime',
 'strawberryfields',
 'tequila',
 'pennylane',
 'qiskit-terra',
 'qiskit-aer',
 'qsharp-compiler',
 'amazon-braket-sdk-python',
 'dwave-system',
 'qiskit-ignis',
 'OpenQL',
 'ProjectQ',
 'pyquil',
 'QuantumLibraries',
 'qulacs',
 'xacc',
 'Cirq']

# %%
def get_comment(df, id_bug):
    relevant_record = df[df["id"] == id_bug].iloc[0]
    return relevant_record["comment"]

get_comment(df=df_bugs, id_bug="1010")
# Out:
# 'Fixer: "Currently qubit truncation will fail for circuits containing barriers across inactive qubits. This fixes the order of circuit transpilation passes to apply the remove barrier pass before the qubit truncation pass."'

# %%
def read_json_content(path):
    """Read the content of a json file."""
    with open(path, 'r') as in_file:
        return json.load(in_file)
    
def write_json(path, data):
    """Write a dictionary to a json file."""
    with open(path, 'w') as out_file:
        json.dump(data, out_file)

# %%
for repo in REPOS[:]:
    
    path_repo = os.path.join(PATH_REPOS, repo)
    bug_folders = os.listdir(path_repo)
    
    for bug_folder in bug_folders:
        #print("-" * 80)
        
        # FIX METADATA
        path_metadata = os.path.join(path_repo, bug_folder, "metadata.json")
        print(path_metadata)
        metadata = read_json_content(path_metadata)
        # print("BEFORE:\n", metadata)
        _ = metadata.pop("author_comment", "")
        id_bug = metadata["id"]
        print(id_bug)
        new_comment = get_comment(df=df_bugs, id_bug=id_bug)
        metadata["annotator_comment"] = new_comment
        # print("AFTER:\n", metadata)
        write_json(path=path_metadata, data=metadata)
        
        # FIX MARKDOWN
        path_markdown = os.path.join(path_repo, bug_folder, f"bug_{id_bug}_comment.md")
        with open(path_markdown, 'w') as out_file:
            out_file.write(new_comment)
            out_file.close()
# Out:
# ../artifacts/minimal_bugfixes/mitiq/mitiq#125/metadata.json
# 1687
# ../artifacts/minimal_bugfixes/mitiq/mitiq#425/metadata.json
# 1697
# ../artifacts/minimal_bugfixes/mitiq/mitiq#525/metadata.json
# 1702
# ../artifacts/minimal_bugfixes/mitiq/mitiq#30/metadata.json
# 1685
# ../artifacts/minimal_bugfixes/mitiq/mitiq#146/metadata.json
# 1688
# ../artifacts/minimal_bugfixes/mitiq/mitiq#598/metadata.json
# 1705
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#744/metadata.json
# 2129
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#533/metadata.json
# 2114
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#147/metadata.json
# 2077
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#229/metadata.json
# 2082
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#270/metadata.json
# 2087
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#133/metadata.json
# 2076
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#55/metadata.json
# 2069
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#256/metadata.json
# 2089
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#351/metadata.json
# 2100
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#278/metadata.json
# 2102
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#576/metadata.json
# 2117
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#407/metadata.json
# 2105
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#349/metadata.json
# 2101
# ../artifacts/minimal_bugfixes/qsharp-runtime/qsharp-runtime#76/metadata.json
# 2070
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#470/metadata.json
# 1854
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#194/metadata.json
# 1836
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#91/metadata.json
# 1828
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#90/metadata.json
# 1829
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#470_B/metadata.json
# 1854,5
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#556/metadata.json
# 1860
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#364/metadata.json
# 1851
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#224/metadata.json
# 1839
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#341/metadata.json
# 1847
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#507/metadata.json
# 1858
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#27/metadata.json
# 1820
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#611/metadata.json
# 1864
# ../artifacts/minimal_bugfixes/strawberryfields/strawberryfields#336/metadata.json
# 1846
# ../artifacts/minimal_bugfixes/tequila/tequila#95/metadata.json
# 1734
# ../artifacts/minimal_bugfixes/tequila/tequila#8/metadata.json
# 1721
# ../artifacts/minimal_bugfixes/tequila/tequila#119/metadata.json
# 1738
# ../artifacts/minimal_bugfixes/tequila/tequila#176/metadata.json
# 1745
# ../artifacts/minimal_bugfixes/tequila/tequila#2/metadata.json
# 1723
# ../artifacts/minimal_bugfixes/tequila/tequila#109/metadata.json
# 1736
# ../artifacts/minimal_bugfixes/tequila/tequila#166/metadata.json
# 1744
# ../artifacts/minimal_bugfixes/tequila/tequila#1/metadata.json
# 1722
# ../artifacts/minimal_bugfixes/tequila/tequila#139/metadata.json
# 1742
# ../artifacts/minimal_bugfixes/tequila/tequila#71/metadata.json
# 1733
# ../artifacts/minimal_bugfixes/tequila/tequila#48/metadata.json
# 1727
# ../artifacts/minimal_bugfixes/tequila/tequila#97/metadata.json
# 1735
# ../artifacts/minimal_bugfixes/tequila/tequila#47/metadata.json
# 1726
# ../artifacts/minimal_bugfixes/tequila/tequila#55/metadata.json
# 1729
# ../artifacts/minimal_bugfixes/pennylane/pennylane#481/metadata.json
# 75
# ../artifacts/minimal_bugfixes/pennylane/pennylane#1451/metadata.json
# 156
# ../artifacts/minimal_bugfixes/pennylane/pennylane#35/metadata.json
# 35
# ../artifacts/minimal_bugfixes/pennylane/pennylane#1586/metadata.json
# 160
# ../artifacts/minimal_bugfixes/pennylane/pennylane#1081/metadata.json
# 128
# ../artifacts/minimal_bugfixes/pennylane/pennylane#849/metadata.json
# 104
# ../artifacts/minimal_bugfixes/pennylane/pennylane#1426/metadata.json
# 154
# ../artifacts/minimal_bugfixes/pennylane/pennylane#1232/metadata.json
# 138
# ../artifacts/minimal_bugfixes/pennylane/pennylane#206/metadata.json
# 53
# ../artifacts/minimal_bugfixes/pennylane/pennylane#385/metadata.json
# 68
# ../artifacts/minimal_bugfixes/pennylane/pennylane#1223/metadata.json
# 136
# ../artifacts/minimal_bugfixes/pennylane/pennylane#709/metadata.json
# 107
# ../artifacts/minimal_bugfixes/pennylane/pennylane#481_B/metadata.json
# 75,5
# ../artifacts/minimal_bugfixes/pennylane/pennylane#1349/metadata.json
# 150
# ../artifacts/minimal_bugfixes/pennylane/pennylane#946/metadata.json
# 110
# ../artifacts/minimal_bugfixes/pennylane/pennylane#1533/metadata.json
# 159
# ../artifacts/minimal_bugfixes/pennylane/pennylane#1243/metadata.json
# 140
# ../artifacts/minimal_bugfixes/pennylane/pennylane#494/metadata.json
# 76
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#4887/metadata.json
# 700
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#557/metadata.json
# 255
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#6554/metadata.json
# 862
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#891/metadata.json
# 567
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#5034/metadata.json
# 679
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#440/metadata.json
# 234
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#3513/metadata.json
# 505
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#5910/metadata.json
# 787
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#61/metadata.json
# 183
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#2704/metadata.json
# 514
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#342/metadata.json
# 225
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#4974/metadata.json
# 663
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#5370/metadata.json
# 733
# ../artifacts/minimal_bugfixes/qiskit-terra/qiskit-terra#3900/metadata.json
# 556
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#1294/metadata.json
# 1096
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#1173/metadata.json
# 1070
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#483/metadata.json
# 980
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#707/metadata.json
# 1012
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#158/metadata.json
# 950
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#167/metadata.json
# 953
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#276/metadata.json
# 964
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#1278/metadata.json
# 1092
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#771/metadata.json
# 1022
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#1132/metadata.json
# 1067
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#767/metadata.json
# 1019
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#1089/metadata.json
# 1057
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#322/metadata.json
# 968
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#693/metadata.json
# 1010
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#1206/metadata.json
# 1076
# ../artifacts/minimal_bugfixes/qiskit-aer/qiskit-aer#1188/metadata.json
# 1073
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#908/metadata.json
# 1222
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#767/metadata.json
# 1216
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#95/metadata.json
# 1175
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#712/metadata.json
# 1212
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#466/metadata.json
# 1195
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#885/metadata.json
# 1221
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#1041/metadata.json
# 1234
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#255/metadata.json
# 1188
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#1008/metadata.json
# 1233
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#1000/metadata.json
# 1230
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#987/metadata.json
# 1229
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#809/metadata.json
# 1217
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#147/metadata.json
# 1178
# ../artifacts/minimal_bugfixes/qsharp-compiler/qsharp-compiler#880/metadata.json
# 1220
# ../artifacts/minimal_bugfixes/amazon-braket-sdk-python/amazon-braket-sdk-python#263/metadata.json
# 1680
# ../artifacts/minimal_bugfixes/amazon-braket-sdk-python/amazon-braket-sdk-python#167/metadata.json
# 1651
# ../artifacts/minimal_bugfixes/amazon-braket-sdk-python/amazon-braket-sdk-python#199/metadata.json
# 1663
# ../artifacts/minimal_bugfixes/amazon-braket-sdk-python/amazon-braket-sdk-python#268/metadata.json
# 1682
# ../artifacts/minimal_bugfixes/amazon-braket-sdk-python/amazon-braket-sdk-python#192/metadata.json
# 1662
# ../artifacts/minimal_bugfixes/amazon-braket-sdk-python/amazon-braket-sdk-python#174/metadata.json
# 1652
# ../artifacts/minimal_bugfixes/amazon-braket-sdk-python/amazon-braket-sdk-python#44/metadata.json
# 1633
# ../artifacts/minimal_bugfixes/amazon-braket-sdk-python/amazon-braket-sdk-python#187/metadata.json
# 1659
# ../artifacts/minimal_bugfixes/amazon-braket-sdk-python/amazon-braket-sdk-python#188/metadata.json
# 1660
# ../artifacts/minimal_bugfixes/amazon-braket-sdk-python/amazon-braket-sdk-python#250/metadata.json
# 1678
# ../artifacts/minimal_bugfixes/amazon-braket-sdk-python/amazon-braket-sdk-python#207/metadata.json
# 1667
# ../artifacts/minimal_bugfixes/dwave-system/dwave-system#276/metadata.json
# 2056
# ../artifacts/minimal_bugfixes/dwave-system/dwave-system#230/metadata.json
# 2052
# ../artifacts/minimal_bugfixes/dwave-system/dwave-system#422/metadata.json
# 2067
# ../artifacts/minimal_bugfixes/dwave-system/dwave-system#418/metadata.json
# 2066
# ../artifacts/minimal_bugfixes/dwave-system/dwave-system#373/metadata.json
# 2064
# ../artifacts/minimal_bugfixes/dwave-system/dwave-system#6/metadata.json
# 2032
# ../artifacts/minimal_bugfixes/dwave-system/dwave-system#16/metadata.json
# 2033
# ../artifacts/minimal_bugfixes/dwave-system/dwave-system#197/metadata.json
# 2043
# ../artifacts/minimal_bugfixes/dwave-system/dwave-system#423/metadata.json
# 2068
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#576/metadata.json
# 33
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#550/metadata.json
# 30
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#567/metadata.json
# 32
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#388/metadata.json
# 16
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#333/metadata.json
# 11
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#240/metadata.json
# 7
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#492/metadata.json
# 27
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#466/metadata.json
# 26
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#231/metadata.json
# 4
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#302/metadata.json
# 10
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#563/metadata.json
# 31
# ../artifacts/minimal_bugfixes/qiskit-ignis/qiskit-ignis#3/metadata.json
# 1
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#107/metadata.json
# 1254
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#427/metadata.json
# 1287
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#287/metadata.json
# 1261
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#295/metadata.json
# 1263
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#332/metadata.json
# 1270
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#10/metadata.json
# 1266
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#428/metadata.json
# 1288
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#139/metadata.json
# 1257
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#62/metadata.json
# 1246
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#44/metadata.json
# 1245
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#375/metadata.json
# 1280
# ../artifacts/minimal_bugfixes/OpenQL/OpenQL#374/metadata.json
# 1279
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#203/metadata.json
# 1116
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#255/metadata.json
# 1118
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#121/metadata.json
# 1112
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#5/metadata.json
# 1102
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#80/metadata.json
# 1108
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#113/metadata.json
# 1111
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#49/metadata.json
# 1107
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#25/metadata.json
# 1103
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#383/metadata.json
# 1123
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#408/metadata.json
# 1126
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#187/metadata.json
# 1115
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#101/metadata.json
# 1110
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#44/metadata.json
# 1105
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#368/metadata.json
# 1122
# ../artifacts/minimal_bugfixes/ProjectQ/ProjectQ#361/metadata.json
# 1121
# ../artifacts/minimal_bugfixes/pyquil/pyquil#1138/metadata.json
# 2007
# ../artifacts/minimal_bugfixes/pyquil/pyquil#1103/metadata.json
# 2005
# ../artifacts/minimal_bugfixes/pyquil/pyquil#174/metadata.json
# 1936
# ../artifacts/minimal_bugfixes/pyquil/pyquil#1010/metadata.json
# 2004
# ../artifacts/minimal_bugfixes/pyquil/pyquil#710/metadata.json
# 1988
# ../artifacts/minimal_bugfixes/pyquil/pyquil#758/metadata.json
# 1991
# ../artifacts/minimal_bugfixes/pyquil/pyquil#384/metadata.json
# 1959
# ../artifacts/minimal_bugfixes/pyquil/pyquil#55/metadata.json
# 1928
# ../artifacts/minimal_bugfixes/pyquil/pyquil#1295/metadata.json
# 2018
# ../artifacts/minimal_bugfixes/QuantumLibraries/QuantumLibraries#303/metadata.json
# 1156
# ../artifacts/minimal_bugfixes/QuantumLibraries/QuantumLibraries#216/metadata.json
# 1149
# ../artifacts/minimal_bugfixes/QuantumLibraries/QuantumLibraries#48/metadata.json
# 1139
# ../artifacts/minimal_bugfixes/qulacs/qulacs#107/metadata.json
# 1775
# ../artifacts/minimal_bugfixes/qulacs/qulacs#73/metadata.json
# 1763
# ../artifacts/minimal_bugfixes/qulacs/qulacs#138/metadata.json
# 1780
# ../artifacts/minimal_bugfixes/qulacs/qulacs#276_B/metadata.json
# 1814,5
# ../artifacts/minimal_bugfixes/qulacs/qulacs#276/metadata.json
# 1814
# ../artifacts/minimal_bugfixes/qulacs/qulacs#229/metadata.json
# 1803
# ../artifacts/minimal_bugfixes/qulacs/qulacs#35/metadata.json
# 1752
# ../artifacts/minimal_bugfixes/qulacs/qulacs#251/metadata.json
# 1808
# ../artifacts/minimal_bugfixes/qulacs/qulacs#196/metadata.json
# 1797
# ../artifacts/minimal_bugfixes/qulacs/qulacs#64/metadata.json
# 1762
# ../artifacts/minimal_bugfixes/qulacs/qulacs#32/metadata.json
# 1750
# ../artifacts/minimal_bugfixes/qulacs/qulacs#101/metadata.json
# 1774
# ../artifacts/minimal_bugfixes/qulacs/qulacs#155/metadata.json
# 1786
# ../artifacts/minimal_bugfixes/xacc/xacc#309_B/metadata.json
# 1900,5
# ../artifacts/minimal_bugfixes/xacc/xacc#161/metadata.json
# 1878
# ../artifacts/minimal_bugfixes/xacc/xacc#37/metadata.json
# 1869
# ../artifacts/minimal_bugfixes/xacc/xacc#362/metadata.json
# 1908
# ../artifacts/minimal_bugfixes/xacc/xacc#309/metadata.json
# 1900
# ../artifacts/minimal_bugfixes/xacc/xacc#411/metadata.json
# 1917
# ../artifacts/minimal_bugfixes/xacc/xacc#298/metadata.json
# 1896
# ../artifacts/minimal_bugfixes/xacc/xacc#288/metadata.json
# 1894
# ../artifacts/minimal_bugfixes/xacc/xacc#238/metadata.json
# 1883
# ../artifacts/minimal_bugfixes/xacc/xacc#423/metadata.json
# 1918
# ../artifacts/minimal_bugfixes/xacc/xacc#370/metadata.json
# 1909
# ../artifacts/minimal_bugfixes/xacc/xacc#370_B/metadata.json
# 1909,5
# ../artifacts/minimal_bugfixes/xacc/xacc#378/metadata.json
# 1911
# ../artifacts/minimal_bugfixes/xacc/xacc#154/metadata.json
# 1876
# ../artifacts/minimal_bugfixes/xacc/xacc#299/metadata.json
# 1897
# ../artifacts/minimal_bugfixes/xacc/xacc#164/metadata.json
# 1879
# ../artifacts/minimal_bugfixes/xacc/xacc#233/metadata.json
# 1882
# ../artifacts/minimal_bugfixes/xacc/xacc#403/metadata.json
# 1915
# ../artifacts/minimal_bugfixes/Cirq/Cirq#1345/metadata.json
# 1372
# ../artifacts/minimal_bugfixes/Cirq/Cirq#3381/metadata.json
# 1518
# ../artifacts/minimal_bugfixes/Cirq/Cirq#2065/metadata.json
# 1417
# ../artifacts/minimal_bugfixes/Cirq/Cirq#2739/metadata.json
# 1464
# ../artifacts/minimal_bugfixes/Cirq/Cirq#3948/metadata.json
# 1571
# ../artifacts/minimal_bugfixes/Cirq/Cirq#691/metadata.json
# 1331
# ../artifacts/minimal_bugfixes/Cirq/Cirq#608/metadata.json
# 1327
# ../artifacts/minimal_bugfixes/Cirq/Cirq#2758/metadata.json
# 1467
# ../artifacts/minimal_bugfixes/Cirq/Cirq#3710/metadata.json
# 1555
# ../artifacts/minimal_bugfixes/Cirq/Cirq#3497/metadata.json
# 1537
# ../artifacts/minimal_bugfixes/Cirq/Cirq#3125/metadata.json
# 1496
# ../artifacts/minimal_bugfixes/Cirq/Cirq#4288/metadata.json
# 1612
